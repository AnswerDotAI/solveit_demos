# %% [markdown]
# This is a template, written in TEMPLATE

# %% [markdown]
# This subfolder also has a template - which is where this note was written!

# %%
a = "And also this variable"

# %% [markdown]
# ^^ Those three messages come from the TEMPLATEs in this subfolder and the main parent folder. There's also a CRAFT in the parent folder, which defines a function we can use here:

# %%
foo()
